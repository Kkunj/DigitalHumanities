# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# ...
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.7 MB/s eta 0:00:00
# ...
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf

# Create a TensorFlow session
with tf.Session() as sess:
    # Restore the computational graph from the .meta file
    saver = tf.train.import_meta_graph('/Users/rpatel/Desktop/6-sem/Digital Humanities/VGG16/VGG16_BigEarthNet-19_labels.meta')
    
    # Restore the weights from the checkpoint files
    saver.restore(sess, 'path_to_your_model/model')

    # Access placeholders, operations, or tensors by name
    # For example:
    graph = tf.get_default_graph()
    input_tensor = graph.get_tensor_by_name('input_tensor_name:0')  # Adjust name as per your graph
    output_tensor = graph.get_tensor_by_name('output_tensor_name:0')  # Adjust name as per your graph

    # Now you can use the model for inference
    # For example:
    result = sess.run(output_tensor, feed_dict={input_tensor: your_input_data})
